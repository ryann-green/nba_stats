# %%
from nba_api.stats.endpoints import teamgamelogs
import pandas as pd
import warnings
import time
warnings.simplefilter('ignore')

current_seasons=teamgamelogs.SeasonNullable.current_season
print(current_seasons)
# Out:
# 2022-23

# %%
df=teamgamelogs.TeamGameLogs(season_nullable=current_seasons).get_data_frames()[0]

# %%
team_games=[]
for i,row in df.iterrows():
    team_game= f"{row['TEAM_ABBREVIATION']}_{row['GAME_ID']}"
    team_games.append(team_game)
df['team_games']=team_games
true_df=df.set_index('team_games')
true_df.index.name = 'team_game'
true_df
# Out:
#                SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION  \
# team_game
# ATL_0022200633     2022-23  1610612737               ATL
# NYK_0022200634     2022-23  1610612752               NYK
# UTA_0022200638     2022-23  1610612762               UTA
# MIN_0022200637     2022-23  1610612750               MIN
# NOP_0022200632     2022-23  1610612740               NOP
# ...                    ...         ...               ...
# HOU_0022200005     2022-23  1610612745               HOU
# LAL_0022200002     2022-23  1610612747               LAL
# BOS_0022200001     2022-23  1610612738               BOS
# PHI_0022200001     2022-23  1610612755               PHI
# GSW_0022200002     2022-23  1610612744               GSW
#
#                              TEAM_NAME     GAME_ID            GAME_DATE  \
# team_game
# ATL_0022200633           Atlanta Hawks  0022200633  2023-01-13T00:00:00
# NYK_0022200634         New York Knicks  0022200634  2023-01-13T00:00:00
# UTA_0022200638               Utah Jazz  0022200638  2023-01-13T00:00:00
# MIN_0022200637  Minnesota Timberwolves  0022200637  2023-01-13T00:00:00
# NOP_0022200632    New Orleans Pelicans  0022200632  2023-01-13T00:00:00
# ...                                ...         ...                  ...
# HOU_0022200005         Houston Rockets  0022200005  2022-10-19T00:00:00
# LAL_0022200002      Los Angeles Lakers  0022200002  2022-10-18T00:00:00
# BOS_0022200001          Boston Celtics  0022200001  2022-10-18T00:00:00
# PHI_0022200001      Philadelphia 76ers  0022200001  2022-10-18T00:00:00
# GSW_0022200002   Golden State Warriors  0022200002  2022-10-18T00:00:00
#
#                     MATCHUP WL   MIN  FGM  ...  REB_RANK  AST_RANK  TOV_RANK  \
# team_game                                  ...
# ATL_0022200633    ATL @ IND  W  48.0   41  ...       183       468       523
# NYK_0022200634    NYK @ WAS  W  48.0   41  ...        66      1252        21
# UTA_0022200638  UTA vs. ORL  W  48.0   36  ...        17      1252      1263
# MIN_0022200637  MIN vs. PHX  W  48.0   47  ...      1061       675       665
# NOP_0022200632    NOP @ DET  W  48.0   42  ...       298       233       890
# ...                     ... ..   ...  ...  ...       ...       ...       ...
# HOU_0022200005    HOU @ ATL  L  48.0   42  ...        66       567       779
# LAL_0022200002    LAL @ GSW  L  48.0   40  ...       298       774      1227
# BOS_0022200001  BOS vs. PHI  W  48.0   46  ...      1111       675       187
# PHI_0022200001    PHI @ BOS  L  48.0   40  ...      1239      1227       523
# GSW_0022200002  GSW vs. LAL  W  48.0   45  ...       298       106       998
#
#                 STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  \
# team_game
# ATL_0022200633       763        57       1187      777       382       631
# NYK_0022200634      1187       274        434      900       281       690
# UTA_0022200638       269        20        241      310       141       690
# MIN_0022200637        33       848        241      777       616       328
# NOP_0022200632       577       848        241      666       281       502
# ...                  ...       ...        ...      ...       ...       ...
# HOU_0022200005      1083       848        645      546       846       926
# LAL_0022200002        63       637        434      310       281       837
# BOS_0022200001       408       848        241     1001       141       173
# PHI_0022200001       408       848        241     1080       202       463
# GSW_0022200002       103       637        434      900       846       266
#
#                 PLUS_MINUS_RANK
# team_game
# ATL_0022200633              574
# NYK_0022200634              499
# UTA_0022200638              499
# MIN_0022200637              461
# NOP_0022200632              423
# ...                         ...
# HOU_0022200005              980
# LAL_0022200002             1091
# BOS_0022200001              302
# PHI_0022200001              938
# GSW_0022200002              163
#
# [1280 rows x 56 columns]

# %%
from oauth2client.service_account import ServiceAccountCredentials
from df2gspread import df2gspread as d2g

# The path of client_secret json file that you have downloaded
# path = '/nfs/home/data/'
 
scopes = ['https://www.googleapis.com/auth/spreadsheets', 
          "https://www.googleapis.com/auth/drive.file", 
          "https://www.googleapis.com/auth/drive"]
creds = ServiceAccountCredentials.from_json_keyfile_name("../gs_creds/client_secret.json", scopes)
def write_googlesheet(df,spreadsheet_key,sheet_title,starting_cell,overwrite):
    d2g.upload(df,
           spreadsheet_key,
           sheet_title,
           credentials=creds,
           col_names=True,
           row_names=True,
           start_cell = starting_cell,
           clean=overwrite)

# %%
true_df.columns
# Out:
# Index(['SEASON_YEAR', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
#        'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M',
#        'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST',
#        'TOV', 'STL', 'BLK', 'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS',
#        'GP_RANK', 'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK',
#        'FGA_RANK', 'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK',
#        'FTM_RANK', 'FTA_RANK', 'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK',
#        'REB_RANK', 'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK',
#        'PF_RANK', 'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK'],
#       dtype='object')

# %%
write_googlesheet(true_df,'1WScIAA7DFu1VuhBjQ2H86KoAWG0K7Qvg6EpRpG6S68I','game_logs','A1',True)

# %%
true_df
# Out:
#                SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION  \
# team_game
# ATL_0022200633     2022-23  1610612737               ATL
# NYK_0022200634     2022-23  1610612752               NYK
# UTA_0022200638     2022-23  1610612762               UTA
# MIN_0022200637     2022-23  1610612750               MIN
# NOP_0022200632     2022-23  1610612740               NOP
# ...                    ...         ...               ...
# HOU_0022200005     2022-23  1610612745               HOU
# LAL_0022200002     2022-23  1610612747               LAL
# BOS_0022200001     2022-23  1610612738               BOS
# PHI_0022200001     2022-23  1610612755               PHI
# GSW_0022200002     2022-23  1610612744               GSW
#
#                              TEAM_NAME     GAME_ID            GAME_DATE  \
# team_game
# ATL_0022200633           Atlanta Hawks  0022200633  2023-01-13T00:00:00
# NYK_0022200634         New York Knicks  0022200634  2023-01-13T00:00:00
# UTA_0022200638               Utah Jazz  0022200638  2023-01-13T00:00:00
# MIN_0022200637  Minnesota Timberwolves  0022200637  2023-01-13T00:00:00
# NOP_0022200632    New Orleans Pelicans  0022200632  2023-01-13T00:00:00
# ...                                ...         ...                  ...
# HOU_0022200005         Houston Rockets  0022200005  2022-10-19T00:00:00
# LAL_0022200002      Los Angeles Lakers  0022200002  2022-10-18T00:00:00
# BOS_0022200001          Boston Celtics  0022200001  2022-10-18T00:00:00
# PHI_0022200001      Philadelphia 76ers  0022200001  2022-10-18T00:00:00
# GSW_0022200002   Golden State Warriors  0022200002  2022-10-18T00:00:00
#
#                     MATCHUP WL   MIN  FGM  ...  REB_RANK  AST_RANK  TOV_RANK  \
# team_game                                  ...
# ATL_0022200633    ATL @ IND  W  48.0   41  ...       183       468       523
# NYK_0022200634    NYK @ WAS  W  48.0   41  ...        66      1252        21
# UTA_0022200638  UTA vs. ORL  W  48.0   36  ...        17      1252      1263
# MIN_0022200637  MIN vs. PHX  W  48.0   47  ...      1061       675       665
# NOP_0022200632    NOP @ DET  W  48.0   42  ...       298       233       890
# ...                     ... ..   ...  ...  ...       ...       ...       ...
# HOU_0022200005    HOU @ ATL  L  48.0   42  ...        66       567       779
# LAL_0022200002    LAL @ GSW  L  48.0   40  ...       298       774      1227
# BOS_0022200001  BOS vs. PHI  W  48.0   46  ...      1111       675       187
# PHI_0022200001    PHI @ BOS  L  48.0   40  ...      1239      1227       523
# GSW_0022200002  GSW vs. LAL  W  48.0   45  ...       298       106       998
#
#                 STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  \
# team_game
# ATL_0022200633       763        57       1187      777       382       631
# NYK_0022200634      1187       274        434      900       281       690
# UTA_0022200638       269        20        241      310       141       690
# MIN_0022200637        33       848        241      777       616       328
# NOP_0022200632       577       848        241      666       281       502
# ...                  ...       ...        ...      ...       ...       ...
# HOU_0022200005      1083       848        645      546       846       926
# LAL_0022200002        63       637        434      310       281       837
# BOS_0022200001       408       848        241     1001       141       173
# PHI_0022200001       408       848        241     1080       202       463
# GSW_0022200002       103       637        434      900       846       266
#
#                 PLUS_MINUS_RANK
# team_game
# ATL_0022200633              574
# NYK_0022200634              499
# UTA_0022200638              499
# MIN_0022200637              461
# NOP_0022200632              423
# ...                         ...
# HOU_0022200005              980
# LAL_0022200002             1091
# BOS_0022200001              302
# PHI_0022200001              938
# GSW_0022200002              163
#
# [1280 rows x 56 columns]

# %% [markdown]
# ####

# %%
from nba_api.stats import endpoints

# %%
player_game_logs=endpoints.playergamelogs.PlayerGameLogs(season_nullable=current_seasons).get_data_frames()[0]
player_game_logs.index.name= "index"

# %%
player_game_logs_real=player_game_logs[['SEASON_YEAR', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID','TEAM_ABBREVIATION', 'GAME_ID', 'GAME_DATE', 'MATCHUP',
       'WL', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM',
       'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK',
       'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS', 'NBA_FANTASY_PTS']]
player_game_logs_real
# Out:
#       SEASON_YEAR  PLAYER_ID        PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  \
# index
# 0         2022-23     203084    Harrison Barnes  1610612758               SAC
# 1         2022-23    1626196    Josh Richardson  1610612759               SAS
# 2         2022-23    1630541        Moses Moody  1610612744               GSW
# 3         2022-23     203926     Doug McDermott  1610612759               SAS
# 4         2022-23    1631103     Malaki Branham  1610612759               SAS
# ...           ...        ...                ...         ...               ...
# 13593     2022-23    1629673       Jordan Poole  1610612744               GSW
# 13594     2022-23     201566  Russell Westbrook  1610612747               LAL
# 13595     2022-23     203952     Andrew Wiggins  1610612744               GSW
# 13596     2022-23     203076      Anthony Davis  1610612747               LAL
# 13597     2022-23       2544       LeBron James  1610612747               LAL
#
#           GAME_ID            GAME_DATE      MATCHUP WL        MIN  ...  AST  \
# index                                                              ...
# 0      0022200640  2023-01-13T00:00:00  SAC vs. HOU  W  36.016667  ...    3
# 1      0022200635  2023-01-13T00:00:00  SAS vs. GSW  L  21.016667  ...    5
# 2      0022200635  2023-01-13T00:00:00    GSW @ SAS  W  18.050000  ...    3
# 3      0022200635  2023-01-13T00:00:00  SAS vs. GSW  L  22.183333  ...    1
# 4      0022200635  2023-01-13T00:00:00  SAS vs. GSW  L  21.783333  ...    2
# ...           ...                  ...          ... ..        ...  ...  ...
# 13593  0022200002  2022-10-18T00:00:00  GSW vs. LAL  W  28.183333  ...    7
# 13594  0022200002  2022-10-18T00:00:00    LAL @ GSW  L  30.683333  ...    3
# 13595  0022200002  2022-10-18T00:00:00  GSW vs. LAL  W  29.465000  ...    4
# 13596  0022200002  2022-10-18T00:00:00    LAL @ GSW  L  35.600000  ...    0
# 13597  0022200002  2022-10-18T00:00:00    LAL @ GSW  L  35.200000  ...    8
#
#        TOV  STL  BLK  BLKA  PF  PFD  PTS  PLUS_MINUS  NBA_FANTASY_PTS
# index
# 0        1    1    0     0   1    3   27          28             41.9
# 1        0    1    1     0   3    3    9         -13             26.1
# 2        0    1    0     0   0    2   12           7             21.9
# 3        0    1    0     0   1    2   14         -24             20.9
# 4        1    0    0     0   4    1   12         -21             16.4
# ...    ...  ...  ...   ...  ..  ...  ...         ...              ...
# 13593    4    2    0     0   2    1   12           1             26.9
# 13594    4    1    0     1   1    3   19          -6             35.7
# 13595    1    1    1     0   5    1   20          25             38.2
# 13596    3    4    1     1   2    7   27         -21             46.2
# 13597    5    0    0     1   2    4   31         -10             56.0
#
# [13598 rows x 32 columns]

# %%
write_googlesheet(player_game_logs_real,'1WScIAA7DFu1VuhBjQ2H86KoAWG0K7Qvg6EpRpG6S68I','player_logs','A1',True)

# %%
from nba_api.stats.static import teams
# get_teams returns a list of 30 dictionaries, each an NBA team.
nba_teams = teams.get_teams()
print('Number of teams fetched: {}'.format(len(nba_teams)))
nba_teams_real=pd.DataFrame(nba_teams)
write_googlesheet(nba_teams_real,'1WScIAA7DFu1VuhBjQ2H86KoAWG0K7Qvg6EpRpG6S68I','teams','A1',True)
# Out:
# Number of teams fetched: 30

# %%
team_ids=nba_teams_real['id']
team_ids
# Out:
# 0     1610612737
# 1     1610612738
# 2     1610612739
# 3     1610612740
# 4     1610612741
# 5     1610612742
# 6     1610612743
# 7     1610612744
# 8     1610612745
# 9     1610612746
# 10    1610612747
# 11    1610612748
# 12    1610612749
# 13    1610612750
# 14    1610612751
# 15    1610612752
# 16    1610612753
# 17    1610612754
# 18    1610612755
# 19    1610612756
# 20    1610612757
# 21    1610612758
# 22    1610612759
# 23    1610612760
# 24    1610612761
# 25    1610612762
# 26    1610612763
# 27    1610612764
# 28    1610612765
# 29    1610612766
# Name: id, dtype: int64

# %%
from nba_api.stats.static import players

# %%
nba_players = players.get_active_players()
print('Number of active players fetched: {}'.format(len(nba_players)))
# Out:
# Number of active players fetched: 582

# %%
nba_players_real=pd.DataFrame(nba_players)
nba_players_real
# Out:
#           id         full_name first_name  last_name  is_active
# 0    1630173  Precious Achiuwa   Precious    Achiuwa       True
# 1     203500      Steven Adams     Steven      Adams       True
# 2    1628389       Bam Adebayo        Bam    Adebayo       True
# 3    1630534      Ochai Agbaji      Ochai     Agbaji       True
# 4    1630583      Santi Aldama      Santi     Aldama       True
# ..       ...               ...        ...        ...        ...
# 577   201152    Thaddeus Young   Thaddeus      Young       True
# 578  1629027        Trae Young       Trae      Young       True
# 579  1630209    Omer Yurtseven       Omer  Yurtseven       True
# 580   203469       Cody Zeller       Cody     Zeller       True
# 581  1627826       Ivica Zubac      Ivica      Zubac       True
#
# [582 rows x 5 columns]

# %%
player_ids=nba_players_real['id']
player_ids
# Out:
# 0      1630173
# 1       203500
# 2      1628389
# 3      1630534
# 4      1630583
#         ...
# 577     201152
# 578    1629027
# 579    1630209
# 580     203469
# 581    1627826
# Name: id, Length: 582, dtype: int64

# %%
write_googlesheet(nba_players_real,'1WScIAA7DFu1VuhBjQ2H86KoAWG0K7Qvg6EpRpG6S68I','players','A1',True)

# %%
top_75_players=endpoints.leagueleaders.LeagueLeaders(season=current_seasons).get_data_frames()[0].iloc[:75]["PLAYER_ID"]
top_75_players
# Out:
# 0     1629029
# 1     1628369
# 2     1628983
# 3      201142
# 4     1628378
#        ...
# 70     203084
# 71    1628989
# 72     201566
# 73    1630581
# 74    1626167
# Name: PLAYER_ID, Length: 75, dtype: int64

# %%
seasons=['2020-21','2021-22','2022-23']

# %%
# ls=[]
# dict={}
# for season in seasons:
#     for team in team_ids[:3]:
#         for player in top_75_players [:3]:
#             try:
#                 player_vs_team=endpoints.teamvsplayer.TeamVsPlayer(vs_player_id=player,team_id=team,opponent_team_id=team,season=season).vs_player_overall.get_data_frame()
#                 pvt_df=player_vs_team[['GROUP_VALUE', 'PLAYER_ID', 'GP', 'W_PCT',
#                        'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA',
#                        'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK', 'BLKA',
#                        'PF', 'PFD', 'PTS', 'PLUS_MINUS', 'NBA_FANTASY_PTS']]
#                 pvt_df['team_id']=team
#                 pvt_df['season']=season
#                 ls.append(pvt_df)
#             except:
#                 print("Variable not found")

# %%
# ls=[]
# dict={}
# for season in seasons:
#     for team in team_ids:
#         for player in top_75_players:
#             try:
#                 player_vs_team=endpoints.teamvsplayer.TeamVsPlayer(vs_player_id=player,team_id=team,opponent_team_id=team,season=season,season_type_playoffs="Regular Season").vs_player_overall.get_data_frame()
#                 pvt_df=player_vs_team[['GROUP_VALUE', 'PLAYER_ID', 'GP', 'W_PCT',
#                        'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA',
#                        'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK', 'BLKA',
#                        'PF', 'PFD', 'PTS', 'PLUS_MINUS', 'NBA_FANTASY_PTS']]
#                 pvt_df['team_id']=team
#                 pvt_df['season']=season
#                 ls.append(pvt_df)
#                 time.sleep(.600)
#             except:
#                 print(f"data for {player} against {team} in {season} not found")

# %%
top_75_ls=[]
for season in seasons:
    print(f"Starting to get data for {season}")
    for player in top_75_players:
        try:
            print(f"getting data for {player}")
            player_game_logs=endpoints.playergamelogs.PlayerGameLogs(season_nullable=season,player_id_nullable=player).get_data_frames()[0]
            player_game_logs.index.name= "initial_index"
            player_game_logs_real=player_game_logs[['SEASON_YEAR', 'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID','TEAM_ABBREVIATION', 'GAME_ID', 'GAME_DATE', 'MATCHUP',
           'WL', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM',
           'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK',
           'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS', 'NBA_FANTASY_PTS']]
            top_75_ls.append(player_game_logs_real)
            time.sleep(1)
        except:
            print(f"No data for {player} in {season}")
# Out:
# Starting to get data for 2020-21
# getting data for 1629029
# getting data for 1628369
# getting data for 1628983
# getting data for 201142
# getting data for 1628378
# getting data for 1627759
# getting data for 203507
# getting data for 201942
# getting data for 203944
# getting data for 1628374
# getting data for 1630162
# getting data for 1629027
# getting data for 203954
# getting data for 203999
# getting data for 1629630
# getting data for 202711
# getting data for 203897
# getting data for 2544
# getting data for 1628398
# getting data for 203903
# getting data for 1628368
# getting data for 1630224
# getting data for 1628973
# getting data for 1629673
# getting data for 1629014
# getting data for 203924
# getting data for 1630532
# getting data for 204001
# getting data for 1627783
# getting data for 203081
# getting data for 201939
# getting data for 1628389
# getting data for 1630169
# getting data for 203468
# getting data for 202681
# getting data for 1626164
# getting data for 1627741
# getting data for 1629640
# getting data for 1629645
# getting data for 1631094
# getting data for 1627734
# getting data for 1629627
# getting data for 1631097
# getting data for 1627749
# getting data for 1629628
# getting data for 202696
# getting data for 1626174
# getting data for 1629636
# getting data for 202331
# getting data for 1626162
# getting data for 1626179
# getting data for 1628384
# getting data for 1628969
# getting data for 1626156
# getting data for 203076
# getting data for 202691
# getting data for 203915
# getting data for 1629639
# getting data for 1629028
# getting data for 1627750
# getting data for 1629018
# getting data for 1629023
# getting data for 1628415
# getting data for 202710
# getting data for 1631093
# getting data for 1627736
# getting data for 202685
# getting data for 202699
# getting data for 1627832
# getting data for 203932
# getting data for 203084
# getting data for 1628989
# getting data for 201566
# getting data for 1630581
# getting data for 1626167
# Starting to get data for 2021-22
# getting data for 1629029
# getting data for 1628369
# getting data for 1628983
# getting data for 201142
# getting data for 1628378
# getting data for 1627759
# getting data for 203507
# getting data for 201942
# getting data for 203944
# getting data for 1628374
# getting data for 1630162
# getting data for 1629027
# getting data for 203954
# getting data for 203999
# getting data for 1629630
# getting data for 202711
# getting data for 203897
# getting data for 2544
# getting data for 1628398
# getting data for 203903
# getting data for 1628368
# getting data for 1630224
# getting data for 1628973
# getting data for 1629673
# getting data for 1629014
# getting data for 203924
# getting data for 1630532
# getting data for 204001
# getting data for 1627783
# getting data for 203081
# getting data for 201939
# getting data for 1628389
# getting data for 1630169
# getting data for 203468
# getting data for 202681
# getting data for 1626164
# getting data for 1627741
# getting data for 1629640
# getting data for 1629645
# getting data for 1631094
# getting data for 1627734
# getting data for 1629627
# getting data for 1631097
# getting data for 1627749
# getting data for 1629628
# getting data for 202696
# No data for 202696 in 2021-22
# getting data for 1626174
# getting data for 1629636
# getting data for 202331
# getting data for 1626162
# getting data for 1626179
# getting data for 1628384
# getting data for 1628969
# getting data for 1626156
# getting data for 203076
# getting data for 202691
# getting data for 203915
# getting data for 1629639
# getting data for 1629028
# getting data for 1627750
# getting data for 1629018
# getting data for 1629023
# getting data for 1628415
# getting data for 202710
# getting data for 1631093
# getting data for 1627736
# getting data for 202685
# getting data for 202699
# getting data for 1627832
# getting data for 203932
# getting data for 203084
# getting data for 1628989
# getting data for 201566
# getting data for 1630581
# getting data for 1626167
# Starting to get data for 2022-23
# getting data for 1629029
# getting data for 1628369
# getting data for 1628983
# getting data for 201142
# getting data for 1628378
# getting data for 1627759
# getting data for 203507
# getting data for 201942
# getting data for 203944
# getting data for 1628374
# getting data for 1630162
# getting data for 1629027
# getting data for 203954
# getting data for 203999
# getting data for 1629630
# getting data for 202711
# getting data for 203897
# getting data for 2544
# getting data for 1628398
# getting data for 203903
# getting data for 1628368
# getting data for 1630224
# getting data for 1628973
# getting data for 1629673
# getting data for 1629014
# getting data for 203924
# getting data for 1630532
# getting data for 204001
# getting data for 1627783
# getting data for 203081
# getting data for 201939
# getting data for 1628389
# getting data for 1630169
# getting data for 203468
# getting data for 202681
# getting data for 1626164
# getting data for 1627741
# getting data for 1629640
# getting data for 1629645
# getting data for 1631094
# getting data for 1627734
# getting data for 1629627
# getting data for 1631097
# getting data for 1627749
# getting data for 1629628
# getting data for 202696
# getting data for 1626174
# getting data for 1629636
# getting data for 202331
# getting data for 1626162
# getting data for 1626179
# getting data for 1628384
# getting data for 1628969
# getting data for 1626156
# getting data for 203076
# getting data for 202691
# getting data for 203915
# getting data for 1629639
# getting data for 1629028
# getting data for 1627750
# getting data for 1629018
# getting data for 1629023
# getting data for 1628415
# getting data for 202710
# getting data for 1631093
# getting data for 1627736
# getting data for 202685
# getting data for 202699
# getting data for 1627832
# getting data for 203932
# getting data for 203084
# getting data for 1628989
# getting data for 201566
# getting data for 1630581
# getting data for 1626167

# %%
top_75=pd.concat(top_75_ls)
opponents=[]
home_or_away=[]
for i,row in top_75.iterrows():
    opponents.append(str(row['MATCHUP'].split(".")[-1].split("@")[-1]))
    if "@" in row['MATCHUP']:
        home_or_away.append("Away")
    else:
        home_or_away.append("Home")
        
top_75['opponents']=opponents
top_75['location']=home_or_away

# %%
top_75
# Out:
#               SEASON_YEAR PLAYER_ID   PLAYER_NAME     TEAM_ID  \
# initial_index
# 0                 2020-21   1629029   Luka Doncic  1610612742
# 1                 2020-21   1629029   Luka Doncic  1610612742
# 2                 2020-21   1629029   Luka Doncic  1610612742
# 3                 2020-21   1629029   Luka Doncic  1610612742
# 4                 2020-21   1629029   Luka Doncic  1610612742
# ...                   ...       ...           ...         ...
# 30                2022-23   1626167  Myles Turner  1610612754
# 31                2022-23   1626167  Myles Turner  1610612754
# 32                2022-23   1626167  Myles Turner  1610612754
# 33                2022-23   1626167  Myles Turner  1610612754
# 34                2022-23   1626167  Myles Turner  1610612754
#
#               TEAM_ABBREVIATION     GAME_ID            GAME_DATE      MATCHUP  \
# initial_index
# 0                           DAL  0022001071  2021-05-16T00:00:00    DAL @ MIN
# 1                           DAL  0022001057  2021-05-14T00:00:00  DAL vs. TOR
# 2                           DAL  0022000154  2021-05-12T00:00:00  DAL vs. NOP
# 3                           DAL  0022001037  2021-05-11T00:00:00    DAL @ MEM
# 4                           DAL  0022001021  2021-05-09T00:00:00    DAL @ CLE
# ...                         ...         ...                  ...          ...
# 30                          IND  0022200147  2022-11-07T00:00:00  IND vs. NOP
# 31                          IND  0022200121  2022-11-04T00:00:00  IND vs. MIA
# 32                          IND  0022200098  2022-10-31T00:00:00    IND @ BKN
# 33                          IND  0022200074  2022-10-28T00:00:00    IND @ WAS
# 34                          IND  0022200061  2022-10-26T00:00:00    IND @ CHI
#
#               WL        MIN  ... STL BLK  BLKA PF PFD  PTS PLUS_MINUS  \
# initial_index                ...
# 0              L  20.738333  ...   2   0     1  1   3   18        -15
# 1              W  34.216667  ...   0   1     0  4   5   20         -5
# 2              W  31.266667  ...   0   0     0  1   3   33         24
# 3              L  25.500000  ...   0   0     0  1   3   12        -23
# 4              W  21.616667  ...   2   0     0  2   4   15          4
# ...           ..        ...  ...  ..  ..   ... ..  ..  ...        ...
# 30             W  36.616667  ...   0   3     1  4   6   37         10
# 31             W  31.436667  ...   0   3     0  4   3   16         -4
# 32             L  20.213333  ...   0   2     2  3   4    7        -21
# 33             W  32.350000  ...   0   5     0  4   5   27         20
# 34             L  24.300000  ...   1   4     1  2   3    5         -8
#
#               NBA_FANTASY_PTS  opponents location
# initial_index
# 0                        36.2        MIN     Away
# 1                        50.5        TOR     Home
# 2                        50.6        NOP     Home
# 3                        20.5        MEM     Away
# 4                        33.5        CLE     Away
# ...                       ...        ...      ...
# 30                       60.9        NOP     Home
# 31                       31.9        MIA     Home
# 32                       18.0        BKN     Away
# 33                       55.0        WAS     Away
# 34                       28.2        CHI     Away
#
# [11124 rows x 34 columns]

# %%
write_googlesheet(top_75.reset_index(),'1WScIAA7DFu1VuhBjQ2H86KoAWG0K7Qvg6EpRpG6S68I','top_75_splits','A1',True)
